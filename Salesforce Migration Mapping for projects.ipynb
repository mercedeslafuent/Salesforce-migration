# %%
from selenium import *
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
#Open chrome automated
driver = webdriver.Chrome('webdriver//chromedriver.exe')
# Out:
# C:\Users\Mercedes\AppData\Local\Temp\ipykernel_6244\1842314104.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('webdriver//chromedriver.exe')

# %%
#Open page jira
jira_page = 'https://id.atlassian.com/login?continue=https%3A%2F%2Fid.atlassian.com%2Fjoin%2Fuser-access%3Fresource%3Dari%253Acloud%253Ajira%253A%253Asite%252F45a1ae92-9f25-4dd1-a628-96d47024ec73%26continue%3Dhttps%253A%252F%252Fnice-ce-cxone-sandbox.atlassian.net&application=jira'
driver.get(jira_page)
email = "mercedes.lafuente@niceincontact.com"
driver.find_element("xpath", '/html/body/div[1]/div/div/div/div[2]/div[2]/div/section/div[2]/form/div[1]/div[1]/div/div/div/input').send_keys(email)
driver.find_element("xpath", '/html/body/div[1]/div/div/div/div[2]/div[2]/div/section/div[2]/form/button').click()

# %%
#Log in
driver.find_element("xpath",'/html/body/div/form[1]/div/div/div[2]/div[1]/div/div/div/div/div[1]/div[3]/div/div/div/div[2]/div[2]/div/input[1]').send_keys(email)
driver.find_element("xpath",'/html/body/div/form[1]/div/div/div[2]/div[1]/div/div/div/div/div[1]/div[3]/div/div/div/div[4]/div/div/div/div/input').click()

# %%
#Manual process

# %%
#Go to page bindings
page_bindings = 'https://nice-ce-cxone-sandbox.atlassian.net/plugins/servlet/ac/com.servicerocket.jira.salesforce/bindings?s=com.servicerocket.jira.salesforce__bindings'
driver.get(page_bindings)

# %%
df = pd.read_csv('oficial_list.csv')

# %%
#Add all the projects of the list
#id for each button mapping
count=28486
timeout = 5
refresh = 5
for row, datos in df.iterrows():
    nameProjects = datos["Projects"]
    #Swith to frame in order to get access
    driver.switch_to.frame(driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[2]/div[3]/div[2]/div/div/iframe'))
    WebDriverWait(driver, 20).until(expected_conditions.element_to_be_clickable(driver.find_element(By.XPATH, '//*[@id="sf-binding-button-add"]'))).click()
    #write and select the project
    WebDriverWait(driver, 20).until(expected_conditions.element_to_be_clickable(driver.find_element(By.XPATH, '//*[@id="s2id_sf-binding-dialog-add-form-select-jira-project"]/a'))).click()
    driver.find_element(By.XPATH, '//*[@id="select2-drop"]/div/input').send_keys(nameProjects)
    #driver.find_element(By.XPATH, '//*[@id="select2-drop"]/ul/li/div').click()
    select_project = expected_conditions.presence_of_element_located((By.XPATH,'//*[@id="select2-drop"]/ul/li/div'))
    WebDriverWait(driver, timeout).until(select_project).click()
    #select the connection
    select_connection = expected_conditions.presence_of_element_located((By.XPATH,'//*[@id="s2id_sf-binding-dialog-form-add-select-connection-id"]/a'))
    WebDriverWait(driver, timeout).until(select_connection).click()
    select_salesforce = expected_conditions.presence_of_element_located((By.XPATH,'//*[@id="select2-drop"]/ul/li/div'))
    WebDriverWait(driver, timeout).until(select_salesforce).click()
    #click to add the project
    WebDriverWait(driver, 20).until(expected_conditions.element_to_be_clickable(driver.find_element(By.XPATH,'/html/body/section/div/footer/div[1]/button[1]'))).click()
    #click to CANCEL the project
    element_present = expected_conditions.presence_of_element_located((By.ID, 'sf-binding-default-mapping-button-cancel'))
    WebDriverWait(driver, timeout).until(element_present).click()
    #id for mapping
    count = count + 1
    WebDriverWait(driver, 20).until(expected_conditions.element_to_be_clickable(driver.find_element(By.ID,'sf-binding-table-{}-operation-configure-mapping'.format(count)))).click();
    time.sleep(20)
    #Again we have to swith to frame because it's a new page
    driver.switch_to.frame(driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[2]/div[3]/div[2]/div/div/iframe'))
    try:
        button = driver.find_element(By.XPATH,"//input[@type='file']")
        button.send_keys("D://FileJSON/oficial_mapping.json")
    except:
        print(nameProjects)
    #return to the main page of bindings
    driver.find_element(By.XPATH,'//*[@id="content"]/div[1]/div/div[1]/div/a').click()
    time.sleep(5)

# %%
driver.switch_to.frame(driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[2]/div[3]/div[2]/div/div/iframe'))
box_content = driver.find_elements(By.ID, 'sf-binding-table-body')
box=box_content[0]
# Out:
# C
# X
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# E
# n
# t
# _
# S
# c
# a
# l
# e
# _
# C
# l
# u
# s
# t
# e
# r
# l
# e
# s
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# e
# v
# O
# P
# S
# _
# S
# S
# P
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# i
# t
# e
# _
# R
# e
# l
# i
# a
# b
# i
# l
# i
# t
# y
# _
# E
# n
# g
# i
# n
# e
# e
# r
# i
# n
# g
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
#
# B
# r
# a
# n
# d
#
# E
# m
# b
# a
# s
# s
# y
#
# C
# u
# s
# t
# o
# m
# e
# r
#
# S
# u
# p
# p
# o
# r
# t
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# C
# D
# _
# D
# e
# v
# O
# p
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# C
# D
# _
# S
# y
# s
# t
# e
# m
# _
# P
# e
# r
# f
# o
# r
# m
# a
# n
# c
# e
# _
# F
# o
# r
# c
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# C
# D
# _
# A
# P
# I
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# g
# e
# n
# t
# W
# o
# r
# k
# s
# p
# a
# c
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# u
# t
# o
# m
# a
# t
# i
# o
# n
# _
# A
# I
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# u
# t
# o
# _
# A
# t
# t
# e
# n
# d
# a
# n
# t
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# X
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# B
# i
# l
# l
# i
# n
# g
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# B
# o
# t
# _
# B
# u
# i
# l
# d
# e
# r
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# C
# T
# O
#
# T
# i
# g
# e
# r
#
# T
# e
# a
# m
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# C
# R
# M
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# C
# X
# o
# n
# e
#
# H
# A
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# C
# X
# o
# n
# e
# _
# W
# o
# r
# k
# s
# t
# r
# e
# a
# m
# _
# D
# e
# v
# O
# p
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# C
# u
# s
# t
# o
# m
# e
# r
# _
# C
# h
# a
# t
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# a
# t
# a
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# a
# t
# a
# _
# S
# t
# r
# e
# a
# m
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# e
# p
# l
# o
# y
# m
# e
# n
# t
# A
# s
# s
# u
# r
# a
# n
# c
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# e
# v
# e
# l
# o
# p
# e
# r
#
# E
# x
# p
# e
# r
# i
# e
# n
# c
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# e
# v
# e
# l
# o
# p
# e
# r
# _
# E
# n
# a
# b
# l
# e
# m
# e
# n
# t
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# F
# i
# l
# e
#
# U
# p
# l
# o
# a
# d
#
# S
# e
# r
# v
# i
# c
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# I
# n
# f
# r
# a
# s
# t
# r
# u
# c
# t
# u
# r
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# M
# e
# d
# i
# a
# _
# S
# e
# r
# v
# i
# c
# e
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# M
# S
# T
# R
# _
# R
# e
# p
# o
# r
# t
# i
# n
# g
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# O
# p
# e
# r
# a
# t
# i
# o
# n
# s
# ,
#
# S
# e
# c
# u
# r
# i
# t
# y
#
# &
#
# C
# o
# m
# p
# l
# i
# a
# n
# c
# e
# ,
#
# a
# n
# d
#
# I
# n
# f
# r
# a
# s
# t
# r
# u
# c
# t
# u
# r
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# O
# c
# t
# o
# p
# u
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# O
# S
# C
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# O
# r
# c
# h
# e
# s
# t
# r
# a
# t
# i
# o
# n
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# O
# u
# t
# b
# o
# u
# n
# d
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# O
# W
# L
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# A
# S
# C
# O
# E
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# a
# t
# r
# o
# n
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# a
# r
# t
# n
# e
# r
# _
# I
# n
# t
# e
# g
# r
# a
# t
# i
# o
# n
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# i
# p
# e
# l
# i
# n
# e
# _
# I
# n
# f
# r
# a
# _
# A
# u
# t
# o
# m
# a
# t
# i
# o
# n
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# l
# a
# t
# f
# o
# r
# m
#
# F
# i
# l
# e
#
# S
# e
# r
# v
# e
# r
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# l
# a
# t
# f
# o
# r
# m
# _
# A
# P
# I
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# l
# a
# t
# f
# o
# r
# m
# _
# D
# e
# v
# O
# p
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# l
# a
# t
# f
# o
# r
# m
# _
# T
# o
# o
# l
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# r
# o
# d
# u
# c
# t
# _
# D
# e
# s
# i
# g
# n
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# R
# e
# a
# l
# -
# T
# i
# m
# e
#
# I
# n
# t
# e
# r
# a
# c
# t
# i
# o
# n
#
# G
# u
# i
# d
# a
# n
# c
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# P
# r
# o
# d
# u
# c
# t
#
# S
# u
# c
# c
# e
# s
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# R
# e
# p
# o
# r
# t
# i
# n
# g
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# &
# C
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# E
# T
#
# T
# o
# o
# l
# s
#
# P
# r
# o
# j
# e
# c
# t
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# F
# _
# E
# i
# n
# s
# t
# e
# i
# n
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# u
# p
# e
# r
# v
# i
# s
# o
# r
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# F
# D
# C
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# T
# e
# l
# e
# m
# e
# t
# r
# y
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# T
# S
# T
# o
# o
# l
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# T
# e
# n
# a
# n
# t
#
# M
# a
# n
# a
# g
# e
# m
# e
# n
# t
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# V
# M
# S
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# V
# o
# i
# c
# e
# _
# A
# s
# _
# S
# e
# r
# v
# i
# c
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# V
# O
# L
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# I
# C
# E
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# C
# D
# _
# U
# I
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# i
# g
# i
# t
# a
# l
# _
# E
# n
# g
# a
# g
# e
# m
# e
# n
# t
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# A
# r
# c
# h
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# M
# A
# X
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# t
# o
# r
# a
# g
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# S
# e
# r
# v
# i
# c
# e
# a
# b
# i
# l
# i
# t
# y
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# D
# a
# t
# a
# _
# L
# a
# k
# e
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# I
# n
# t
# e
# g
# r
# a
# t
# i
# o
# n
# s
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# C
# X
# _
# U
# s
# e
# r
# H
# u
# b
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
#
#
# N
# I
# C
# E
# -
# U
# p
# t
# i
# v
# i
# t
# y
#
# S
# F
#
# C
# o
# n
# n
# e
# c
# t
# i
# o
# n
#
# E
# d
# i
# t
# M
# a
# p
# p
# i
# n
# g
